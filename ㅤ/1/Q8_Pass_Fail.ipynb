# %% [markdown]
# # Q8 Pass Fail

# %%
# Q8: Pass Fail Series
import pandas as pd

marks = pd.Series([35,55,78,22,90,60,41,30])
result = marks.apply(lambda x: "Fail" if x<40 else x)

print(result)
print("Passed:", (marks>=40).sum())
