# %% [markdown]
# EndSem_Set1_Q8_Outlier_IQR_Boxplot.ipynb

# %%
# Q8: Outlier Detection using IQR and Boxplot

from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

plt.boxplot(df["sepal length (cm)"])
plt.title("Before Removing Outliers")
plt.show()

Q1 = df["sepal length (cm)"].quantile(0.25)
Q3 = df["sepal length (cm)"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df_clean = df[(df["sepal length (cm)"] >= lower) & (df["sepal length (cm)"] <= upper)]

plt.boxplot(df_clean["sepal length (cm)"])
plt.title("After Removing Outliers")
plt.show()
